# %% [markdown]
#   # THE PRICE IS RIGHT

# %%
import pandas as pd

# %%
import sqlite3

# %%
import glob

# %%
import os.path

# %%
import io

# %% [markdown]
# ## import Showcase data from Excel

# %%
ShowcaseStats = pd.read_csv("https://raw.githubusercontent.com/koryvette/python/master/project/Showcase_spin.csv")

# %%
ShowcaseStats.head()
# Out:
#    Season  First spinner won  Second spinner won  Third spinner won
# 0      29                 92                 115                121
# 1      30                 93                 133                124
# 2      31                103                 129                118
# 3      32                106                 114                130
# 4      33                119                 106                125

# %% [markdown]
# ## read to SQLite

# %%
import sqlite3

# %%
con = sqlite3.connect('priceright.db')

# %%
df_win = pd.read_csv('https://raw.githubusercontent.com/koryvette/python/master/project/Game_stats_Win.csv')

# %%
df_win.head()
# Out:
#    Season  Any_Number  Balance_Game  Barkers_Bargain_Bar  Barkers_MarkerS  \
# 0      29          12             0                   23                3
# 1      30          11             0                   21                5
# 2      31           8             0                   24                5
# 3      32           5             0                   18                3
# 4      33           9             0                   15                3
#
#    Bonkers  Bonus_Game  Bullseye  Buy_or_Sell  Card_Game      ...       \
# 0        0           4         9            7          4      ...
# 1       11           5        10            4          5      ...
# 2       10           2        12            6          5      ...
# 3        6           8         9            7          3      ...
# 4        7           8         8            4          3      ...
#
#    Switcheroo  Take_Two  Temptation  10_Chances  Thats_Too_Much  3_Strikes  \
# ...

# %%
df_win.to_sql('CREATE TABLE Winners ("Season","Any Number integer", "Balance Game integer", "Barkers Bargain Bar integer", "Barkers MarkerS integer", "Bonkers integer", "Bonus Game integer", "Bullseye integer", "Buy or Sell integer", "Card Game integer", "Check Game integer", "Check-Out integer", "Clearance Sale integer", "Cliff Hangers integer", "Clock Game integer", "Coming or Going integer", "Cover Up integer", "Credit Card integer", "Danger Price integer", "Dice Game integer", "Do the Math integer", "Double Cross integer", "Double Prices integer", "Eazy az 1 2 3 integer", "Five Price Tags integer", "Flip Flop integer", "Freeze Frame integer", "Gas Money integer", "Golden Road integer", "Grand Game integer", "Gridlock! integer", "Grocery Game integer", "Half Off integer", "Hi Lo integer", "Hit Me integer", "Hole in One integer", "Hot Seat integer", "Its in the Bag integer", "Joker integer", "Let em Roll integer", "Line em Up integer", "Lucky Seven integer", "Magic_Number integer", "Make Your Move integer", "Master Key integer", "Money Game integer", "More or Less integer", "Most ExpenSive integer", "Now....or Then integer", "On the Spot integer", "One Away integer", "1 Right Price integer", "1 Wrong Price integer", "Pass The Buck integer", "Pathfinder integer", "Pay the Rent integer", "Penny Ante integer", "Pick-a-Number integer", "Pick-a-Pair integer", "Plinko integer", "Pocket ¢hange integer", "Poker Game integer", "Punch a Bunch integer", "Push Over integer", "Race Game integer", "Range Game integer", "Rat Race integer", "Safe Crackers integer", "Secret X integer", "Shell Game integer", "Shopping Spree integer", "Side by Side integer", "Spelling Bee integer", "Squeeze Play integer", "Stack the Deck integer", "Step Up integer", "Swap Meet integer", "Switch? integer", "Switcheroo integer", "Take Two integer", "Temptation integer", "10 Chances integer", "Thats Too Much! integer", "3 Strikes integer", "Time is Money integer", "Triple Play integer", "2 for the Price of 1 integer", "Vend-O-Price integer" ', con,  if_exists='replace')

# %%
Winners.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-399eecfb5a20> in <module>()
# ----> 1 Winners.head()
#
# NameError: name 'Winners' is not defined

# %%
df_lose = pd.read_csv('https://raw.githubusercontent.com/koryvette/python/master/project/Game_stats_Loss.csv')

# %%
df_lose.head()
# Out:
#    Season  Any_Number  Balance_Game  Barkers_Bargain_Bar  Barkers_MarkerS  \
# 0      29          15             0                    8                5
# 1      30          12             0                    8                2
# 2      31          14             0                    7                2
# 3      32          20             0                   13                4
# 4      33          16             0                   10                3
#
#    Bonkers  Bonus_Game  Bullseye  Buy_or_Sell  Card_Game      ...       \
# 0        0           2         4            1         14      ...
# 1       11           0         2            3         12      ...
# 2        6           4         2            1          9      ...
# 3        9           1         2            0         11      ...
# 4        5           1         2            2         14      ...
#
#    Switcheroo  Take_Two  Temptation  10_Chances  Thats_Too_Much  3_Strikes  \
# ...

# %%
sql = "SELECT * FROM Losers"

# %%
df_showcase = pd.read_csv('https://raw.githubusercontent.com/koryvette/python/master/project/Showcase_spin.csv')

# %%
df_showcase.to_sql('CREATE TABLE Showcase (Season varchar, First_spinner_won integer, Second_spinner_won integer, Third_spinner_won integer', con,  if_exists='replace')
# Out:
# C:\Users\79kor\Anaconda3\lib\site-packages\pandas\core\generic.py:2127: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %%
df_showcase.head()
# Out:
#    Season  First spinner won  Second spinner won  Third spinner won
# 0      29                 92                 115                121
# 1      30                 93                 133                124
# 2      31                103                 129                118
# 3      32                106                 114                130
# 4      33                119                 106                125

# %%
Losers.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-960f728a87a1> in <module>()
# ----> 1 Losers.head()
#
# NameError: name 'Losers' is not defined

# %%
con.close()

# %%
for row in df_lose:
    cursor.execute('INSERT INTO testcsv(Season varchar, First_spinner_won integer, Second_spinner_won integer, Third_spinner_won integer', con,  if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-6ad93a16eba8> in <module>()
#       1 for row in df_lose:
# ----> 2     cursor.execute('INSERT INTO testcsv(Season varchar, First_spinner_won integer, Second_spinner_won integer, Third_spinner_won integer', con,  if_exists='replace')
#
# NameError: name 'cursor' is not defined

# %% [markdown]
# ## import Winners data from Excel

# %%
WinnerStats = pd.read_csv("https://raw.githubusercontent.com/koryvette/python/master/project/Game_stats_Win.csv")

# %%
WinnerStats.head()
# Out:
#    Season  Any Number  Balance Game  Barker's Bargain Bar  Barker's Marker$  \
# 0      29          12             0                    23                 3
# 1      30          11             0                    21                 5
# 2      31           8             0                    24                 5
# 3      32           5             0                    18                 3
# 4      33           9             0                    15                 3
#
#    Bonkers  Bonus Game  Bullseye  Buy or Sell  Card Game      ...       \
# 0        0           4         9            7          4      ...
# 1       11           5        10            4          5      ...
# 2       10           2        12            6          5      ...
# 3        6           8         9            7          3      ...
# 4        7           8         8            4          3      ...
#
#    Switcheroo  Take Two  Temptation  10 Chances  That's Too Much!  3 Strikes  \
# ...

# %% [markdown]
# ## import Losers data from Excel

# %%
LoserStats = pd.read_csv("https://raw.githubusercontent.com/koryvette/python/master/project/Game_stats_Loss.csv")

# %%
LoserStats.head()
# Out:
#    Season  Any Number  Balance Game  Barker's Bargain Bar  Barker's Marker$  \
# 0      29          15             0                     8                 5
# 1      30          12             0                     8                 2
# 2      31          14             0                     7                 2
# 3      32          20             0                    13                 4
# 4      33          16             0                    10                 3
#
#    Bonkers  Bonus Game  Bullseye  Buy or Sell  Card Game      ...       \
# 0        0           2         4            1         14      ...
# 1       11           0         2            3         12      ...
# 2        6           4         2            1          9      ...
# 3        9           1         2            0         11      ...
# 4        5           1         2            2         14      ...
#
#    Switcheroo  Take Two  Temptation  10 Chances  That's Too Much!  3 Strikes  \
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ylabel('Season')
plt.xlabel('Showcase Spinner position')

plt.plot(ShowcaseStats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a0ecb196eaeb> in <module>()
#       4 plt.xlabel('Showcase Spinner position')
#       5
# ----> 6 plt.plot(ShowcaseStats)
#
# NameError: name 'ShowcaseStats' is not defined

# %%
ef main():
    database = "C:\Users\79kor\priceisright.db"
 
    sql_create_projects_table = """ CREATE TABLE IF NOT EXISTS projects (
                                        id integer PRIMARY KEY,
                                        name text NOT NULL,
                                        begin_date text,
                                        end_date text
                                    ); """
