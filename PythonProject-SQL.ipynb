# %% [markdown]
#   # THE PRICE IS RIGHT

# %%
import pandas as pd

# %%
import sqlite3

# %% [markdown]
# ## import Showcase data from Excel

# %%
ShowcaseExcel = pd.ExcelFile("F:\Kory\coding\Python_files\project\Showcase_spin.xlsx")

# %%
ShowcaseStats = ShowcaseExcel.parse('Sheet2')

ShowcaseStats.head()
# Out:
#    Season  First spinner won  Second spinner won  Third spinner won
# 0      29                 92                 115                121
# 1      30                 93                 133                124
# 2      31                103                 129                118
# 3      32                106                 114                130
# 4      33                119                 106                125

# %% [markdown]
# ## read to SQLite

# %%
import sqlite3

# %%
db = sqlite3.connect('F:\Kory\coding\Python_files\project\priceisright.db')

# %%
def create table():
    c.execute('CREATE TABLE(ShowcaseStats)')
# Out:
#   File "<ipython-input-9-f7582da43aa6>", line 1
#     def create table():
#                    ^
# SyntaxError: invalid syntax

# %%
create table()
# Out:
#   File "<ipython-input-10-1d11922e0566>", line 1
#     create table()
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## import Winners data from Excel

# %%
WinnersExcel = pd.ExcelFile("F:\Kory\coding\Python_files\project\Game_stats_Win.xlsx")

# %%
WinnerStats = WinnersExcel.parse('Sheet2')

WinnerStats.head()
# Out:
#    Season  Any Number  Balance Game  Barker's Bargain Bar  Barker's Marker$  \
# 0      29          12             0                    23                 3
# 1      30          11             0                    21                 5
# 2      31           8             0                    24                 5
# 3      32           5             0                    18                 3
# 4      33           9             0                    15                 3
#
#    Bonkers  Bonus Game  Bullseye  Buy or Sell  Card Game      ...       \
# 0        0           4         9            7          4      ...
# 1       11           5        10            4          5      ...
# 2       10           2        12            6          5      ...
# 3        6           8         9            7          3      ...
# 4        7           8         8            4          3      ...
#
#    Switcheroo  Take Two  Temptation  10 Chances  That's Too Much!  3 Strikes  \
# ...

# %% [markdown]
# ## import Losers data from Excel

# %%
LoserExcel = pd.ExcelFile("F:\Kory\coding\Python_files\project\Game_stats_Loss.xlsx")

# %%
LoserStats = LoserExcel.parse('Sheet2')

LoserStats.head()
# Out:
#    Season  Any Number  Balance Game  Barker's Bargain Bar  Barker's Marker$  \
# 0      29          15             0                     8                 5
# 1      30          12             0                     8                 2
# 2      31          14             0                     7                 2
# 3      32          20             0                    13                 4
# 4      33          16             0                    10                 3
#
#    Bonkers  Bonus Game  Bullseye  Buy or Sell  Card Game      ...       \
# 0        0           2         4            1         14      ...
# 1       11           0         2            3         12      ...
# 2        6           4         2            1          9      ...
# 3        9           1         2            0         11      ...
# 4        5           1         2            2         14      ...
#
#    Switcheroo  Take Two  Temptation  10 Chances  That's Too Much!  3 Strikes  \
# ...

# %%
import matplotlib.pyplot as plt
plt.ylabel('Season')
plt.xlabel('Showcase Spinner position')

plt.plot(ShowcaseStats)
